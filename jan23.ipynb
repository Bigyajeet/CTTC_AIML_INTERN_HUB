# %%
pip install opencv-python
# Out:
# ...
#    ---------------------------------------- 0.0/39.5 MB ? eta -:--:--
#    ---------------------------------------- 0.0/39.5 MB ? eta -:--:--
#    ---------------------------------------- 0.0/39.5 MB 393.8 kB/s eta 0:01:41
#    ---------------------------------------- 0.1/39.5 MB 563.7 kB/s eta 0:01:10
#    ---------------------------------------- 0.1/39.5 MB 595.3 kB/s eta 0:01:07
#    ---------------------------------------- 0.2/39.5 MB 958.4 kB/s eta 0:00:41
#    ---------------------------------------- 0.3/39.5 MB 923.9 kB/s eta 0:00:43
#    ---------------------------------------- 0.4/39.5 MB 1.3 MB/s eta 0:00:30
#     --------------------------------------- 0.5/39.5 MB 1.5 MB/s eta 0:00:27
#     --------------------------------------- 0.7/39.5 MB 1.8 MB/s eta 0:00:23
#     --------------------------------------- 0.8/39.5 MB 1.9 MB/s eta 0:00:21
#    - -------------------------------------- 1.1/39.5 MB 2.3 MB/s eta 0:00:17
# ...

# %%
import cv2
import numpy as np
