# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
year=np.arange(2001,2005,1)
Domestic=[2258,2441,2491,2352]
Industrial=[2184,2971,3270,3742]
plt.bar(year+0.0,Domestic,width=0.25,color='g')
plt.bar(year+0.25,Industrial,width=0.25,color='r')
plt.xticks([2001,2002,2003,2004],rotation=45)
# Out:
# ([<matplotlib.axis.XTick at 0x1236b2506d0>,
# ...
#  [Text(2001, 0, '2001'),
#   Text(2002, 0, '2002'),
#   Text(2003, 0, '2003'),
#   Text(2004, 0, '2004')])

# %%
states=['AP','OR','MP']
worker=[100,200,150]
non_workers=[200,100,150]

#x-axis position
x=np.arange(len(states))

#plotting stacked bars

plt.bar(x,worker,color='royalblue',label='workers')
plt.bar(x,non_workers,bottom=worker,color='darkorange',label='non_workers')

#titles and labels
plt.xlabel('states')
plt.ylabel('workers')
plt.title("states vs worker")
plt.xticks(x,states,rotation=45)
plt.legend()
plt.show()

# %%
#Scatter plot vs bar plot
x2=[3,5,4,7,2,10,7,8]
y2=[2,6,4,9,6,9,3,10]
plt.bar(x2,y2,width=0.05,color='green')

x=[3,5,4,7,2,10,7,8]
y=[2,6,4,9,6,9,3,10]
plt.scatter(x,y,s=300,color='gold',marker='*',edgecolors='orange',linewidths=10)

x1=[3,5,4,7,2,10,7,8]
y1=[2,6,4,9,6,9,3,10]
plt.scatter(x1,y1,color='brown')
plt.title("Scatter plot")
plt.xlabel('x-axis')
plt.ylabel('y-axis')
plt.show()

# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
iris=pd.read_csv(r"C:\Users\BIGYAJEET\Downloads\iris\iris.data",header=None)

# %%
iris.head()
# Out:
#      0    1    2    3            4
# 0  5.1  3.5  1.4  0.2  Iris-setosa
# 1  4.9  3.0  1.4  0.2  Iris-setosa
# 2  4.7  3.2  1.3  0.2  Iris-setosa
# 3  4.6  3.1  1.5  0.2  Iris-setosa
# 4  5.0  3.6  1.4  0.2  Iris-setosa

# %%
iris.columns=['SL','SW','PL','PW','CLASS']

# %%
iris
# Out:
#       SL   SW   PL   PW           CLASS
# 0    5.1  3.5  1.4  0.2     Iris-setosa
# 1    4.9  3.0  1.4  0.2     Iris-setosa
# 2    4.7  3.2  1.3  0.2     Iris-setosa
# 3    4.6  3.1  1.5  0.2     Iris-setosa
# 4    5.0  3.6  1.4  0.2     Iris-setosa
# ..   ...  ...  ...  ...             ...
# 145  6.7  3.0  5.2  2.3  Iris-virginica
# 146  6.3  2.5  5.0  1.9  Iris-virginica
# 147  6.5  3.0  5.2  2.0  Iris-virginica
# 148  6.2  3.4  5.4  2.3  Iris-virginica
# 149  5.9  3.0  5.1  1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
iris.isnull().sum()
# Out:
# SL       0
# SW       0
# PL       0
# PW       0
# CLASS    0
# dtype: int64

# %%
for i in iris.columns:
    print(i,":",'\n',iris[i].unique(),'\n')
# Out:
# SL :
#  [5.1 4.9 4.7 4.6 5.  5.4 4.4 4.8 4.3 5.8 5.7 5.2 5.5 4.5 5.3 7.  6.4 6.9
#  6.5 6.3 6.6 5.9 6.  6.1 5.6 6.7 6.2 6.8 7.1 7.6 7.3 7.2 7.7 7.4 7.9]
#
# SW :
#  [3.5 3.  3.2 3.1 3.6 3.9 3.4 2.9 3.7 4.  4.4 3.8 3.3 4.1 4.2 2.3 2.8 2.4
#  2.7 2.  2.2 2.5 2.6]
#
# PL :
#  [1.4 1.3 1.5 1.7 1.6 1.1 1.2 1.  1.9 4.7 4.5 4.9 4.  4.6 3.3 3.9 3.5 4.2
#  3.6 4.4 4.1 4.8 4.3 5.  3.8 3.7 5.1 3.  6.  5.9 5.6 5.8 6.6 6.3 6.1 5.3
#  5.5 6.7 6.9 5.7 6.4 5.4 5.2]
#
# PW :
#  [0.2 0.4 0.3 0.1 0.5 0.6 1.4 1.5 1.3 1.6 1.  1.1 1.8 1.2 1.7 2.5 1.9 2.1
#  2.2 2.  2.4 2.3]
#
# CLASS :
#  ['Iris-setosa' 'Iris-versicolor' 'Iris-virginica']

# %%
#distribution plot
sns.distplot(iris.SL)
plt.show()

# %%
sns.displot(iris.SL)
plt.show()

# %%
sns.displot(iris.SL,fill=False,hatch='*',color='orange')
plt.show()

# %%
sns.kdeplot(iris.SL,fill=True,color='g',hatch='/')
plt.show()

# %%
sns.distplot(iris.SL[iris.CLASS=='Iris-setosa'])
sns.distplot(iris.SL[iris.CLASS=='Iris-virginica'])
sns.distplot(iris.SL[iris.CLASS=='Iris-versicolor'])
plt.show()

# %%
sns.displot(iris.SL[iris.CLASS=='Iris-setosa'])
sns.displot(iris.SL[iris.CLASS=='Iris-virginica'])
sns.displot(iris.SL[iris.CLASS=='Iris-versicolor'])
plt.show()

# %%
sns.kdeplot(iris.SL[iris.CLASS=='Iris-setosa'])
sns.kdeplot(iris.SL[iris.CLASS=='Iris-virginica'])
sns.kdeplot(iris.SL[iris.CLASS=='Iris-versicolor'])
plt.show()

# %%
sns.histplot(iris.SL[iris.CLASS=='Iris-setosa'])
sns.histplot(iris.SL[iris.CLASS=='Iris-virginica'])
sns.histplot(iris.SL[iris.CLASS=='Iris-versicolor'])
plt.show()

# %%
sns.histplot(data=iris)
plt.show()

# %%
sns.kdeplot(data=iris,fill=True,hatch='/')
plt.show()

# %%
#box plot
sns.boxplot(x=iris.CLASS,y=iris.SW,hue=iris.CLASS)
plt.show()

# %%
#VIOLIN PLOT
sns.violinplot(x=iris.CLASS,y=iris.SW,hue=iris.CLASS)
plt.show()

# %%
sns.swarmplot(x=iris.CLASS,y=iris.SW,hue=iris.CLASS)
plt.show()

# %%
sns.stripplot(x=iris.CLASS,y=iris.SW,hue=iris.CLASS)
plt.show()

# %%
#boxenplot()
sns.boxenplot(x=iris.CLASS,y=iris.SW,hue=iris.CLASS)
plt.show()

# %%
sns.pointplot(x=iris.CLASS,y=iris.SW,hue=iris.CLASS)
plt.show()

# %%
sns.scatterplot(x=iris.SL,y=iris.PL,hue=iris.CLASS)
plt.show()

# %%
#joint plot
sns.jointplot(data=iris)
plt.show()

# %%
sns.jointplot(data=iris,kind='kde')
plt.show()
