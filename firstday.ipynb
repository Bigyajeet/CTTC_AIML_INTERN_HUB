# %%
help('keyword')
# Out:
# Help on module keyword:
#
# NAME
#     keyword - Keywords (from "Grammar/python.gram")
#
# MODULE REFERENCE
#     https://docs.python.org/3.11/library/keyword.html
#
#     The following documentation is automatically generated from the Python
#     source files.  It may be incomplete, incorrect or include features that
#     are considered implementation detail and may vary between Python
#     implementations.  When in doubt, consult the module reference at the
#     location listed above.
#
# DESCRIPTION
#     This file is automatically generated; please don't muck it up!
#
#     To update the symbols in this file, 'cd' to the top directory of
#     the python source tree and run:
#
#         PYTHONPATH=Tools/peg_generator python3 -m pegen.keywordgen         Grammar/python.gram         Grammar/Tokens         Lib/keyword.py
#
#     Alternatively, you can run 'make regen-keyword'.
#
# FUNCTIONS
#     iskeyword = __contains__(...) method of builtins.frozenset instance
# ...

# %%
import keyword
keyword.iskeyword('id')
# Out:
# False

# %%
'bigyajeet'.isidentifier()
# Out:
# True

# %%
'123bigya'.isidentifier()
# Out:
# False

# %%
'_bik'.isidentifier()
# Out:
# True

# %%
'bik-'.isidentifier()
# Out:
# False

# %%
a=20
print(a)
# Out:
# 20

# %%
id(a)
# Out:
# 140729753650568

# %%
id(help)
# Out:
# 2170589307920

# %%
print(print("hello"))
# Out:
# hello
# None

# %%
a=input("enter the first value:")
print(a)
# Out:
# enter the first value: 120
# 120

# %%
print("the value of a is",a)
# Out:
# the value of a is 120

# %%
a=6
print(a,"the type of a is",type(a))
# Out:
# 6 the type of a is <class 'int'>

# %%
z=2+3j
print(type(z))
# Out:
# <class 'complex'>

# %%
str="Bigyajeet "
print(str)
print(str[0:5])
# Out:
# Bigyajeet
# Bigya

# %%
str[:5]
# Out:
# 'bigya'

# %%
str[2:]
# Out:
# 'gyajeet '

# %%
a="helloworld "
print(a[0:5:2])
# Out:
# hlo

# %%
print(str[::-1])
# Out:
#  teejaygib

# %%
str*2
# Out:
# 'bigyajeet bigyajeet '

# %%
str+"patra"
# Out:
# 'bigyajeet patra'

# %%
str.capitalize()
# Out:
# 'Bigyajeet '

# %%
str.lower()
# Out:
# 'bigyajeet '

# %%
str.upper()
# Out:
# 'BIGYAJEET '

# %%
str.swapcase()
# Out:
# 'BIGYAJEET '

# %%
str.capitalize()
# Out:
# 'Bigyajeet '

# %%
str.swapcase()
# Out:
# 'bIGYAJEET '

# %%
#removing whitespaces
tra=" my name is bigyajeet "
tra.strip()
# Out:
# 'my name is bigyajeet'

# %%
ra=" my name is bigyajeet "
ra.lstrip()
# Out:
# 'my name is bigyajeet '

# %%
ra.rstrip()
# Out:
# ' my name is bigyajeet'

# %%
#list defined
list=["hello",13,3,True,2+2j,20.2]
print(list)
# Out:
# ['hello', 13, 3, True, (2+2j), 20.2]

# %%
print(type(list))
# Out:
# <class 'list'>

# %%
print(list[0])
# Out:
# hello

# %%
print(list[0:3])
# Out:
# ['hello', 13, 3]

# %%
#reverse
print(list[::-1])
# Out:
# [20.2, (2+2j), True, 3, 13, 'hello']

# %%
print(list[:4])
# Out:
# ['hello', 13, 3, True]

# %%
#append
list.append(112)

# %%
print(list)
# Out:
# ['hello', 13, 3, True, (2+2j), 20.2, 112]

# %%
list*2
# Out:
# ['hello',
#  13,
#  3,
#  True,
#  (2+2j),
#  20.2,
#  112,
#  'hello',
#  13,
#  3,
#  True,
#  (2+2j),
#  20.2,
#  112]

# %%
list1=["patra",1]
#concatenate list
list+list1
# Out:
# ['hello', 13, 3, True, (2+2j), 20.2, 112, 'patra', 1]

# %%
list.count(1)
# Out:
# 1

# %%
#list.remove(1)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[76], line 1
# ----> 1 list.remove(1)
#
# ValueError: list.remove(x): x not in list

# %%
print(list.reverse())
# Out:
# None

# %%
list
# Out:
# ['hello', 13, 3, (2+2j), 20.2, 112]

# %%
list.remove(3)

# %%
list
# Out:
# [112, 20.2, (2+2j), 13, 'hello']

# %%
list.pop(2)
# Out:
# (2+2j)

# %%
list.index(112)
# Out:
# 0

# %%
tuple=(1,'bigyajeet',2,3,4,4)

# %%
tuple
# Out:
# (1, 'bigyajeet', 2, 3, 4, 4)

# %%
tuple[0]
# Out:
# 1

# %%
tuple[0:2]
# Out:
# (1, 'bigyajeet')

# %%
tuple[2:]
# Out:
# (2, 3, 4, 4)

# %%
tuple*2
# Out:
# (1, 'bigyajeet', 2, 3, 4, 4, 1, 'bigyajeet', 2, 3, 4, 4)

# %%
tuple=(4,7,6,6,"bigya",6)

# %%
tuple
# Out:
# (4, 7, 6, 6, 'bigya', 6)

# %%
tuple.index("bigya")
# Out:
# 4

# %%
#dictionary
dict1={'name':'bigyajeet','code':98887777,'dept':'cse'}

# %%
dict1
# Out:
# {'name': 'bigyajeet', 'code': 98887777, 'dept': 'cse'}

# %%
dict1['name']
# Out:
# 'bigyajeet'

# %%
dict1.keys()
# Out:
# dict_keys(['name', 'code', 'dept'])

# %%
dict1.values()
# Out:
# dict_values(['bigyajeet', 98887777, 'cse'])

# %%
dict1.get('name')
# Out:
# 'bigyajeet'

# %%
dict1.items()
# Out:
# dict_items([('name', 'bigyajeet'), ('code', 98887777), ('dept', 'cse')])

# %% [markdown]
# ###

# %%
dict2={'code':999}
dict1.update(dict2)

# %%
dict1
# Out:
# {'name': 'bigyajeet', 'code': 999, 'dept': 'cse'}

# %%
#set
a={2,3,4,5}

# %%
a.add(8)

# %%
a
# Out:
# {2, 3, 4, 5, 8}

# %%
b={2,3}
a.union(b)
# Out:
# {2, 3, 4, 5, 8}

# %%
a.intersection(b)
# Out:
# {2, 3}

# %%
b.issubset(a)
# Out:
# True

# %%
b.isdisjoint(a)
# Out:
# False

# %%
a.remove(3)

# %%
a
# Out:
# {2, 4, 5, 8}

# %%
a={2,3,4,5,6}
b={1,2,3}
a.symmetric_difference(b)
# Out:
# {1, 4, 5, 6}
