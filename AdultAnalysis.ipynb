# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data=pd.read_csv(r"C:\Users\BIGYAJEET\Downloads\adult.data",
                 delimiter=" *, *",
                 engine='python',header=None)
data
# Out:
#        0                 1       2           3   4                   5   \
# 0      39         State-gov   77516   Bachelors  13       Never-married
# 1      50  Self-emp-not-inc   83311   Bachelors  13  Married-civ-spouse
# 2      38           Private  215646     HS-grad   9            Divorced
# 3      53           Private  234721        11th   7  Married-civ-spouse
# 4      28           Private  338409   Bachelors  13  Married-civ-spouse
# ...    ..               ...     ...         ...  ..                 ...
# 32556  27           Private  257302  Assoc-acdm  12  Married-civ-spouse
# 32557  40           Private  154374     HS-grad   9  Married-civ-spouse
# 32558  58           Private  151910     HS-grad   9             Widowed
# 32559  22           Private  201490     HS-grad   9       Never-married
# 32560  52      Self-emp-inc  287927     HS-grad   9  Married-civ-spouse
#
#                       6              7      8       9      10  11  12  \
# ...

# %%
data.columns=['age','workclass','fnlwgt','education',
              'education_num','marital_status','occupation','relationship','race','sex','capitalgain','capitalloss','hoursperweek','native_country',
             'salary']

# %%
data
# Out:
#        age         workclass  fnlwgt   education  education_num  \
# 0       39         State-gov   77516   Bachelors             13
# 1       50  Self-emp-not-inc   83311   Bachelors             13
# 2       38           Private  215646     HS-grad              9
# 3       53           Private  234721        11th              7
# 4       28           Private  338409   Bachelors             13
# ...    ...               ...     ...         ...            ...
# 32556   27           Private  257302  Assoc-acdm             12
# 32557   40           Private  154374     HS-grad              9
# 32558   58           Private  151910     HS-grad              9
# 32559   22           Private  201490     HS-grad              9
# 32560   52      Self-emp-inc  287927     HS-grad              9
#
#            marital_status         occupation   relationship   race     sex  \
# 0           Never-married       Adm-clerical  Not-in-family  White    Male
# ...

# %%
data.isnull().sum()
# Out:
# age               0
# workclass         0
# fnlwgt            0
# education         0
# education_num     0
# marital_status    0
# occupation        0
# relationship      0
# race              0
# sex               0
# capitalgain       0
# capitalloss       0
# hoursperweek      0
# native_country    0
# salary            0
# dtype: int64

# %%
data.shape
# Out:
# (32561, 15)

# %%
data1=data.describe(include='all')
data1
# Out:
#                  age workclass        fnlwgt education  education_num  \
# count   32561.000000     32561  3.256100e+04     32561   32561.000000
# unique           NaN         9           NaN        16            NaN
# top              NaN   Private           NaN   HS-grad            NaN
# freq             NaN     22696           NaN     10501            NaN
# mean       38.581647       NaN  1.897784e+05       NaN      10.080679
# std        13.640433       NaN  1.055500e+05       NaN       2.572720
# min        17.000000       NaN  1.228500e+04       NaN       1.000000
# 25%        28.000000       NaN  1.178270e+05       NaN       9.000000
# 50%        37.000000       NaN  1.783560e+05       NaN      10.000000
# 75%        48.000000       NaN  2.370510e+05       NaN      12.000000
# max        90.000000       NaN  1.484705e+06       NaN      16.000000
#
#             marital_status      occupation relationship   race    sex  \
# ...

# %%
data.dtypes
# Out:
# age                int64
# workclass         object
# fnlwgt             int64
# education         object
# education_num      int64
# marital_status    object
# occupation        object
# relationship      object
# race              object
# sex               object
# capitalgain        int64
# capitalloss        int64
# hoursperweek       int64
# native_country    object
# salary            object
# dtype: object

# %%
for i in data.columns:
    print(i,':','\n',data[i].unique())
# Out:
# age :
#  [39 50 38 53 28 37 49 52 31 42 30 23 32 40 34 25 43 54 35 59 56 19 20 45
#  22 48 21 24 57 44 41 29 18 47 46 36 79 27 67 33 76 17 55 61 70 64 71 68
#  66 51 58 26 60 90 75 65 77 62 63 80 72 74 69 73 81 78 88 82 83 84 85 86
#  87]
# workclass :
#  ['State-gov' 'Self-emp-not-inc' 'Private' 'Federal-gov' 'Local-gov' '?'
#  'Self-emp-inc' 'Without-pay' 'Never-worked']
# fnlwgt :
#  [ 77516  83311 215646 ...  34066  84661 257302]
# education :
#  ['Bachelors' 'HS-grad' '11th' 'Masters' '9th' 'Some-college' 'Assoc-acdm'
#  'Assoc-voc' '7th-8th' 'Doctorate' 'Prof-school' '5th-6th' '10th'
#  '1st-4th' 'Preschool' '12th']
# education_num :
#  [13  9  7 14  5 10 12 11  4 16 15  3  6  2  1  8]
# marital_status :
#  ['Never-married' 'Married-civ-spouse' 'Divorced' 'Married-spouse-absent'
#  'Separated' 'Married-AF-spouse' 'Widowed']
# occupation :
#  ['Adm-clerical' 'Exec-managerial' 'Handlers-cleaners' 'Prof-specialty'
#  'Other-service' 'Sales' 'Craft-repair' 'Transport-moving'
# ...

# %%
for value in ['workclass','occupation']:
    print(value,":",sum(data[value]=='?'))
# Out:
# workclass : 1836
# occupation : 1843

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
for value in ["workclass",'occupation']:
    data[value].replace(['?'],data1[value][2],inplace=True)

# %%
for value in ["workclass",'occupation']:
    print(value,":",sum(data[value]=='?'))
# Out:
# workclass : 0
# occupation : 0

# %%
data.dtypes
# Out:
# age                int64
# workclass         object
# fnlwgt             int64
# education         object
# education_num      int64
# marital_status    object
# occupation        object
# relationship      object
# race              object
# sex               object
# capitalgain        int64
# capitalloss        int64
# hoursperweek       int64
# native_country    object
# salary            object
# dtype: object

# %%
data
# Out:
#        age         workclass  fnlwgt   education  education_num  \
# 0       39         State-gov   77516   Bachelors             13
# 1       50  Self-emp-not-inc   83311   Bachelors             13
# 2       38           Private  215646     HS-grad              9
# 3       53           Private  234721        11th              7
# 4       28           Private  338409   Bachelors             13
# ...    ...               ...     ...         ...            ...
# 32556   27           Private  257302  Assoc-acdm             12
# 32557   40           Private  154374     HS-grad              9
# 32558   58           Private  151910     HS-grad              9
# 32559   22           Private  201490     HS-grad              9
# 32560   52      Self-emp-inc  287927     HS-grad              9
#
#            marital_status         occupation   relationship   race     sex  \
# 0           Never-married       Adm-clerical  Not-in-family  White    Male
# ...

# %%
for value in ["workclass",'occupation','relationship']:
    print(i,':','\n',data[i].unique())
# Out:
# salary :
#  ['<=50K' '>50K']
# salary :
#  ['<=50K' '>50K']
# salary :
#  ['<=50K' '>50K']

# %%
col =[('age','hoursperweek'),
      ('education_num','hoursperweek'),
      ('age', 'fnlwgt')]
for xcol, ycol in col:
    plt.figure(figsize=(8, 5)) 
    sns.scatterplot(x=data[xcol],
                    y=data[ycol],
                    color='teal',
                    alpha=0.7,
                    s=50)
    plt.xlabel(xcol)
    plt.ylabel(ycol)
    plt.title(f'{xcol.replace("_", " ").title()} vs. {ycol.replace("_", " ").title()}', fontsize=14, fontweight='bold')
    plt.grid(True, linestyle='--', alpha=0.6)
    
    plt.show()

# %%
d=data1.corr(numeric_only=True)
sns.heatmap(d,annot=True)
# Out:
# <Axes: >

# %%
col =[('age','hoursperweek'),
      ('education_num','hoursperweek'),
      ('age', 'fnlwgt')]
for xcol, ycol in col:
    plt.figure(figsize=(8, 5)) 
    sns.barplot(x=data[xcol],
                    y=data[ycol],
                    color='teal',
                    alpha=0.7)
    plt.xlabel(xcol)
    plt.ylabel(ycol)
    plt.title(f'{xcol.replace("_", " ").title()} vs. {ycol.replace("_", " ").title()}', fontsize=14, fontweight='bold')
    plt.grid(True, linestyle='--', alpha=0.6)
    
    plt.show()

# %%
sns.scatterplot(x=data.age,y=data.hoursperweek,hue=data.education_num)
# Out:
# <Axes: xlabel='age', ylabel='hoursperweek'>

# %%
sns.lineplot(x=data.education_num,y=data.hoursperweek,hue=data.sex)
# Out:
# <Axes: xlabel='education_num', ylabel='hoursperweek'>

# %%
sns.lineplot(data=data1,x=data1.hoursperweek,y=data1.education_num)
# Out:
# <Axes: xlabel='hoursperweek', ylabel='education_num'>

# %%
sns.distplot(data.education_num[data.salary=='<=50K'],label='No salary')
sns.distplot(data.education_num[data.salary=='>50K'],label='salary') 
plt.legend()
plt.show()

# %%
sns.distplot(data.hoursperweek[data.salary=='<=50K'],label='No salary')
sns.distplot(data.hoursperweek[data.salary=='>50K'],label='salary') 
plt.legend()
plt.show()

# %%
sns.distplot(data.capitalloss[data.salary=='<=50K'],label='No salary')
sns.distplot(data.capitalloss[data.salary=='>50K'],label='salary') 
plt.legend()
plt.show()

# %%
sns.distplot(data.capitalgain[data.salary=='<=50K'],label='No salary')
sns.distplot(data.capitalgain[data.salary=='>50K'],label='salary') 
plt.legend()
plt.show()

# %%
plt.figure(figsize=(12, 7))
sns.countplot(data=data, x='relationship', hue='sex', palette='viridis')
plt.title('Count of Relationship by Sex')
plt.xlabel('Relationship')
plt.ylabel('Count')
plt.xticks(rotation=45, ha='right')
plt.legend(title='Sex')
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()

# %%
plt.figure(figsize=(12, 7))
sns.countplot(data=data, x='occupation', hue='relationship', palette='viridis')
plt.title("by relationship")
plt.xlabel('Relationship')
plt.ylabel('Count')
plt.xticks(rotation=45, ha='right')
plt.legend(title='relationship')
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()

# %%
data1=data.drop(['education_num','hoursperweek','capitalloss','fnlwgt','marital_status'],axis=1)

# %%
data1
# Out:
#        age         workclass   education         occupation   relationship  \
# 0       39         State-gov   Bachelors       Adm-clerical  Not-in-family
# 1       50  Self-emp-not-inc   Bachelors    Exec-managerial        Husband
# 2       38           Private     HS-grad  Handlers-cleaners  Not-in-family
# 3       53           Private        11th  Handlers-cleaners        Husband
# 4       28           Private   Bachelors     Prof-specialty           Wife
# ...    ...               ...         ...                ...            ...
# 32556   27           Private  Assoc-acdm       Tech-support           Wife
# 32557   40           Private     HS-grad  Machine-op-inspct        Husband
# 32558   58           Private     HS-grad       Adm-clerical      Unmarried
# 32559   22           Private     HS-grad       Adm-clerical      Own-child
# 32560   52      Self-emp-inc     HS-grad    Exec-managerial           Wife
#
#         race     sex  capitalgain native_country salary
# ...

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
data1.occupation=le.fit_transform(data1.occupation)
le1=LabelEncoder()
data1.sex=le1.fit_transform(data1.sex)
le2=LabelEncoder()
data1.workclass=le2.fit_transform(data1.workclass)
le3=LabelEncoder()
data1.education=le3.fit_transform(data1.education)
le4=LabelEncoder()
data1.race=le4.fit_transform(data1.race)
le5=LabelEncoder()
data1.native_country=le5.fit_transform(data1.native_country)
le6=LabelEncoder()
data1.relationship=le6.fit_transform(data1.relationship)
le7=LabelEncoder()
data1.salary=le7.fit_transform(data1.salary)

# %%
data1
# Out:
#        age  workclass  education  occupation  relationship  race  sex  \
# 0       39          6          9           0             1     4    1
# 1       50          5          9           3             0     4    1
# 2       38          3         11           5             1     4    1
# 3       53          3          1           5             0     2    1
# 4       28          3          9           9             5     2    0
# ...    ...        ...        ...         ...           ...   ...  ...
# 32556   27          3          7          12             5     4    0
# 32557   40          3         11           6             0     4    1
# 32558   58          3         11           0             4     4    0
# 32559   22          3         11           0             3     4    1
# 32560   52          4         11           3             5     4    0
#
#        capitalgain  native_country  salary
# 0             2174              39       0
# ...

# %%
ip=data1.drop(['salary','age','native_country'],axis=1)
ip
# Out:
#        workclass  education  occupation  relationship  race  sex  capitalgain
# 0              6          9           0             1     4    1         2174
# 1              5          9           3             0     4    1            0
# 2              3         11           5             1     4    1            0
# 3              3          1           5             0     2    1            0
# 4              3          9           9             5     2    0            0
# ...          ...        ...         ...           ...   ...  ...          ...
# 32556          3          7          12             5     4    0            0
# 32557          3         11           6             0     4    1            0
# 32558          3         11           0             4     4    0            0
# 32559          3         11           0             3     4    1            0
# 32560          4         11           3             5     4    0        15024
#
# [32561 rows x 7 columns]

# %%
op=data1['salary']

# %%
#tain test split
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(ip,op,test_size=0.3,random_state=42)

# %%
#standard scalar transform
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
x_train=sc.fit_transform(x_train)
x_test=sc.fit_transform(x_test)

# %%
#logistic regression
from sklearn.linear_model import LogisticRegression
alg1=LogisticRegression()
alg1.fit(x_train,y_train)
# Out:
# LogisticRegression()

# %%
yp=alg1.predict(x_test)
yp
# Out:
# array([0, 0, 0, ..., 0, 0, 1])

# %%
df=pd.DataFrame({'y':list(y_test),'prediction':yp})

# %%
from sklearn.metrics import confusion_matrix,ConfusionMatrixDisplay
cm=confusion_matrix(y_test,yp)
cm
# Out:
# array([[7343,  112],
#        [1842,  472]], dtype=int64)

# %%
cm1=ConfusionMatrixDisplay(cm)
cm1.plot()
plt.show()

# %%
#svm
from sklearn import svm
salg=svm.SVC(kernel='rbf',C=1000,gamma=0.01,random_state=42)
salg.fit(x_train,y_train)
yp4=salg.predict(x_test)

# %%
from sklearn import metrics
acc=metrics.accuracy_score(y_test,yp4)
recall=metrics.recall_score(y_test,yp4)
precision=metrics.precision_score(y_test,yp4)
f1=metrics.f1_score(y_test,yp4)

# %%
print(acc)
print(recall)
print(precision)
print(f1)
# Out:
# 0.8031528303818201
# 0.20181503889369057
# 0.860036832412523
# 0.32691634581729084
