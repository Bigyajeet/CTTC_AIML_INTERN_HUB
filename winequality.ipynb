# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
data=pd.read_csv(r"winequalityred.csv",sep=';')
data
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
# ...

# %%
data.columns=['fixed_acidity', 'volatile_acidity', 'citric_acid', 'residual_sugar',
       'chlorides', 'free_sulfur_dioxide', 'total_sulfur_dioxide', 'density',
       'pH', 'sulphates', 'alcohol','quality']

# %%
data
# Out:
#       fixed_acidity  volatile_acidity  citric_acid  residual_sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
# ...

# %%
data.isnull().sum()
# Out:
# fixed acidity           0
# volatile acidity        0
# citric acid             0
# residual sugar          0
# chlorides               0
# free sulfur dioxide     0
# total sulfur dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 0
# dtype: int64

# %%
data.dtypes
# Out:
# fixed acidity           float64
# volatile acidity        float64
# citric acid             float64
# residual sugar          float64
# chlorides               float64
# free sulfur dioxide     float64
# total sulfur dioxide    float64
# density                 float64
# pH                      float64
# sulphates               float64
# alcohol                 float64
# quality                   int64
# dtype: object

# %%
cols=['fixed_acidity', 'volatile_acidity', 'citric_acid', 'residual_sugar',
       'chlorides', 'free_sulfur_dioxide', 'total_sulfur_dioxide', 'density',
       'pH', 'sulphates', 'alcohol']

# %%
cols
# Out:
# ['fixed_acidity',
#  'volatile_acidity',
#  'citric_acid',
#  'residual_sugar',
#  'chlorides',
#  'free_sulfur_dioxide',
#  'total_sulfur_dioxide',
#  'density',
#  'pH',
#  'sulphates',
#  'alcohol']

# %%
c=data.corr()
plt.figure(figsize=(20,12))
sns.heatmap(c,annot=True)
# Out:
# <Axes: >

# %%
for col in cols:  
     plt.figure(figsize=(6,4))
     sns.barplot(x=col, y='quality', data=data)
     plt.title(f'quality vs {col}')
     plt.xlabel(col)
     plt.ylabel('area')
     plt.show()

# %%
sns.scatterplot(x=data.alcohol,y=data.quality)
# Out:
# <Axes: xlabel='alcohol', ylabel='quality'>

# %%
for col in cols: 
    plt.figure(figsize=(8, 4))
    sns.lineplot(x='quality', y=col, data=data)
    plt.title(f' {col} by quality')
    plt.xlabel('Wine Quality')
    plt.ylabel(col)
    plt.tight_layout()
    plt.show()

# %%
ip=data.drop('quality',axis=1)

# %%
op=data['quality']

# %%
from sklearn.model_selection import train_test_split
xtr,xts,ytr,yts=train_test_split(ip,op,test_size=0.2)

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
xtr=sc.fit_transform(xtr)
xts= sc.transform(xts)

# %%
#knn
from sklearn.neighbors import KNeighborsClassifier
classifier=KNeighborsClassifier(n_neighbors=3)
classifier.fit(xtr,ytr)
yp=classifier.predict(xts)
import sklearn.metrics
recall=metrics.recall_score(yts,yp,average='macro')
accuracy=metrics.accuracy_score(yts,yp)
print(recall)
print(accuracy)
# Out:
# 0.27357983360672566
# 0.553125

# %%
#logistic Regression
from sklearn.linear_model import LogisticRegression
alg=LogisticRegression()
alg.fit(xtr,ytr)

yp2=alg.predict(xts)

from sklearn import metrics
cm=metrics.confusion_matrix(yts,yp2)

accuracy=metrics.accuracy_score(yts,yp)
recall=metrics.recall_score(yts,yp,average='macro')
print(accuracy)
print(recall)
# Out:
# 0.553125
# 0.27357983360672566

# %%
#naive bayes
from sklearn.naive_bayes import GaussianNB
clf=GaussianNB()
clf.fit(xtr,ytr)

yp3=clf.predict(xts)

# %%
from sklearn import metrics
recall=metrics.recall_score(yts,yp3,average='macro')
accuracy=metrics.accuracy_score(yts,yp3)
print(recall)
print(accuracy)
# Out:
# 0.3371335022314661
# 0.571875

# %%
#svm
from sklearn import svm
salg=svm.SVC(kernel='rbf',C=1000,gamma=0.01)
salg.fit(xtr,ytr)
yp4=salg.predict(xts)

# %%
from sklearn import metrics
recall=metrics.recall_score(yts,yp4,average='macro')
accuracy=metrics.accuracy_score(yts,yp4)
print(recall)
print(accuracy)
# Out:
# 0.3079241478204214
# 0.603125

# %%
#DECISIONTREECLASSIFIER
from sklearn.tree import DecisionTreeClassifier
clf=DecisionTreeClassifier(criterion='entropy')

#train decision tree classifier
clf=clf.fit(xtr,ytr)

#predict the response for the dataset
y_pred=clf.predict(xts)

from sklearn import metrics
accuracy2=metrics.accuracy_score(yts,y_pred)
recall2=metrics.recall_score(yts,y_pred,average='macro')
print(recall2)
print(accuracy2)
# Out:
# 0.2894127436002196
# 0.565625

# %%
#RANDOMFOREST CLASSIFIER
from sklearn.ensemble import RandomForestClassifier
clf1=RandomForestClassifier(criterion='entropy',random_state=0)

#train decision tree classifier
clf1=clf1.fit(xtr,ytr)

#predict the response for the dataset
y_pred1=clf1.predict(xts)

from sklearn import metrics
cm=metrics.confusion_matrix(yts,yp)

accuracy=metrics.accuracy_score(yts,y_pred1)
recall=metrics.recall_score(yts,y_pred1,average='macro')

print(recall)
print(accuracy)
# Out:
# 0.3213391345354465
# 0.65625

# %%
#adaptive booster
from sklearn.ensemble import AdaBoostClassifier
a=AdaBoostClassifier(n_estimators=500,learning_rate=0.001,estimator=clf)
a.fit(xtr,ytr)
yp5=a.predict(xts)

recall=metrics.recall_score(yts,yp5,average='macro')
accuracy=metrics.accuracy_score(yts,yp5)
print(recall)
print(accuracy)
# Out:
# 0.28973136253197723
# 0.565625

# %%
#GRADIENTBOOSTING
from sklearn.ensemble import GradientBoostingClassifier
a=GradientBoostingClassifier(n_estimators=1000,learning_rate=0.1)
a.fit(xtr,ytr)
yp6=a.predict(xts)

recall=metrics.recall_score(yts,yp6,average='macro')
accuracy=metrics.accuracy_score(yts,yp6)
print(recall)
print(accuracy)
# Out:
# 0.34005583707850323
# 0.6875
