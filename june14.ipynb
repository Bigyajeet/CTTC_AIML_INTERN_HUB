# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
data=pd.read_csv(r"C:\Users\BIGYAJEET\Downloads\maintenance_data.csv")
data
# Out:
#      lifetime  broken  pressureInd  moistureInd  temperatureInd   team  \
# 0          56       0    92.178854   104.230204       96.517159  TeamA
# 1          81       1    72.075938   103.065701       87.271062  TeamC
# 2          60       0    96.272254    77.801376      112.196170  TeamA
# 3          86       1    94.406461   108.493608       72.025374  TeamC
# 4          34       0    97.752899    99.413492      103.756271  TeamB
# ..        ...     ...          ...          ...             ...    ...
# 995        88       1    88.589759   112.167556       99.861456  TeamB
# 996        88       1   116.727075   110.871332       95.075631  TeamA
# 997        22       0   104.026778    88.212873       83.221220  TeamB
# 998        78       0   104.911649   104.257296       83.421491  TeamA
# 999        63       0   116.901354    99.998694       47.641493  TeamB
#
#       provider
# 0    Provider4
# 1    Provider4
# 2    Provider1
# 3    Provider2
# 4    Provider1
# ..         ...
# ...

# %%
data.isnull().sum()
# Out:
# lifetime          0
# broken            0
# pressureInd       0
# moistureInd       0
# temperatureInd    0
# team              0
# provider          0
# dtype: int64

# %%
data.shape
# Out:
# (1000, 7)

# %%
data.dtypes
# Out:
# lifetime            int64
# broken              int64
# pressureInd       float64
# moistureInd       float64
# temperatureInd    float64
# team               object
# provider           object
# dtype: object

# %%
data1=data.describe(include='all')
data1
# Out:
#            lifetime       broken  pressureInd  moistureInd  temperatureInd  \
# count   1000.000000  1000.000000  1000.000000  1000.000000     1000.000000
# unique          NaN          NaN          NaN          NaN             NaN
# top             NaN          NaN          NaN          NaN             NaN
# freq            NaN          NaN          NaN          NaN             NaN
# mean      55.195000     0.397000    98.599338    99.376723      100.628541
# std       26.472737     0.489521    19.964052     9.988726       19.633060
# min        1.000000     0.000000    33.481917    58.547301       42.279598
# 25%       34.000000     0.000000    85.558076    92.771764       87.676913
# 50%       60.000000     0.000000    97.216997    99.433959      100.592277
# 75%       80.000000     1.000000   112.253190   106.120762      113.662885
# max       93.000000     1.000000   173.282541   128.595038      172.544140
#
#          team   provider
# count    1000       1000
# ...

# %%
for i in data.columns:
    print(i,':','\n',data[i].unique())
# Out:
# lifetime :
#  [56 81 60 86 34 30 68 65 23 38 29 82 80 48 92 88 74 61 35 26 63 79 53 73
#  13 36 31 25 58 19 84 12 15 43  1 20 16  3 18  7 47 39 57  4 24 28 49 76
#  52  8 40 46  5 41 93 77 62 85 55 33 17 45  9 72 50 42 44 54 64 27 22 59
#  66 83 14 51 71 21 78  6 69 89  2 67 87 11 10 32 37 90]
# broken :
#  [0 1]
# pressureInd :
#  [ 92.17885406  72.07593772  96.27225443  94.40646126  97.75289859
#   87.67880097  94.61417404  96.48330289 105.486158    99.17823531
#   97.81784409  67.81225145  86.36611059  76.14465414 103.1072633
#   88.41407945  84.35504868  79.66925455  86.22910861  84.17942039
#  100.0059233  115.6075596   97.69718903 101.4156229  118.9786971
#  102.1127749  129.1243378  109.0330362  107.2980695  127.2639544
#  138.1911205   72.55408417  95.21464918  91.24713174  81.55537698
#   69.13459519 132.8574784   54.73533145  84.89864628  94.15228726
#   84.34406647  95.75352436 123.9284399  101.5053508  120.9455502
# ...

# %%
colss=['lifetime','broken','pressureInd','moistureInd','temperatureInd','team','provider']
for i, col in enumerate(colss):
    plt.subplot(3, 3, i + 1)
    sns.histplot(data[col], kde=True)
    plt.title(f'Distribution of {col}')
plt.tight_layout()

plt.show()

# %%
colss=['lifetime','pressureInd','moistureInd','temperatureInd','team','provider']
plt.figure(figsize=(15, 10))
for i, col in enumerate(colss):
    plt.subplot(3, 3, i + 1)
    sns.boxplot(x='broken', y=col, data=data)
    plt.title(f'{col} by broken')
plt.tight_layout()
plt.show()

# %%
colss=['lifetime','pressureInd','moistureInd','temperatureInd','team','provider']
plt.figure(figsize=(15, 10))
for i, col in enumerate(colss):
    plt.subplot(3, 3, i + 1)
    sns.boxenplot(x='broken', y=col, data=data)
    plt.title(f'{col} by broken')
plt.tight_layout()
plt.show()

# %%
sns.countplot(x=data.lifetime[data.broken==1],label='broken')
sns.countplot(x=data.lifetime[data.broken==0],label='Not broken')
# Out:
# <Axes: xlabel='lifetime', ylabel='count'>

# %%
sns.countplot(x=data.pressureInd[data.broken==1],label='broken')
sns.countplot(x=data.pressureInd[data.broken==0],label='Not broken')
# Out:
# <Axes: xlabel='pressureInd', ylabel='count'>

# %%
sns.countplot(x=data.moistureInd[data.broken==1],label='broken')
sns.countplot(x=data.moistureInd[data.broken==0],label='Not broken')
# Out:
# <Axes: xlabel='moistureInd', ylabel='count'>

# %%
sns.countplot(x=data.temperatureInd,hue=data.broken)
# Out:
# <Axes: xlabel='temperatureInd', ylabel='count'>

# %%
sns.countplot(x=data.provider,hue=data.broken)
# Out:
# <Axes: xlabel='provider', ylabel='count'>

# %%
sns.countplot(x=data.team,hue=data.broken)
# Out:
# <Axes: xlabel='team', ylabel='count'>
